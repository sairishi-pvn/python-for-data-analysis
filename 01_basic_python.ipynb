# %%
print("Hello world")
# Out:
# Hello world

# %%
a = 10
b = 20
a + b
# Out:
# 30

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])
arr * 2
# Out:
# array([2, 4, 6, 8])

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

plt.plot(x, y)
plt.show()
